# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pandas import DataFrame
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
passengers = pd.read_csv("AirPassengers.csv")
passengers["Month"] = pd.to_datetime(passengers.Month)
passengers = passengers.set_index("Month")
passengers
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
df = pd.read_csv("DailyDelhiClimateTrain.csv")
temp = df.iloc[:, :2]
temp.set_index("date", inplace=True)
temp.index = pd.to_datetime(temp.index)
temp
# Out:
#              meantemp
# date
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000
# ...               ...
# 2016-12-28  17.217391
# 2016-12-29  15.238095
# 2016-12-30  14.095238
# 2016-12-31  15.052632
# 2017-01-01  10.000000
#
# [1462 rows x 1 columns]

# %%
plot_acf(temp)
plt.title("Autocorrelation of Temperatures")
plt.xlabel("Lags")
plt.ylabel("Autocorrelations")
# Out:
# Text(0, 0.5, 'Autocorrelations')

# %%
plot_acf(temp, lags=100)
plt.title("Autocorrelation of Temperatures")
plt.xlabel("Lags")
plt.ylabel("Autocorrelations")
# Out:
# Text(0, 0.5, 'Autocorrelations')

# %%
plot_pacf(temp)
plt.title("Partial Autocorrelation of Temperatures")
plt.xlabel("Lags")
plt.ylabel("Autocorrelations")
# Out:
# Text(0, 0.5, 'Autocorrelations')

# %%
plot_acf(passengers, lags=50)
plt.title("Autocorrelation of Passengers")
plt.xlabel("Lags")
plt.ylabel("Autocorrelations")
# Out:
# Text(0, 0.5, 'Autocorrelations')

# %%
plot_acf(passengers)
plt.title("Autocorrelation of Passengers")
plt.xlabel("Lags")
plt.ylabel("Autocorrelations")
# Out:
# Text(0, 0.5, 'Autocorrelations')

# %%
plot_pacf(passengers)
plt.title("Partial Autocorrelation of Passengers")
plt.xlabel("Lags")
plt.ylabel("Autocorrelations")
# Out:
# Text(0, 0.5, 'Autocorrelations')

# %% [markdown]
# temp

# %%
X = temp.meantemp
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,10))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# C:\Users\Jacob\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=30.474441, expected=29.875000
# C:\Users\Jacob\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=30.261757, expected=30.750000
# C:\Users\Jacob\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted=30.304691, expected=32.000000
# C:\Users\Jacob\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-12c4f9b8aeb3> in <module>
# ----> 1 rmse = sqrt(mean_squared_error(test, predictions))
#       2 print('Test RMSE: %.3f' % rmse)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     253
#     254     """
# --> 255     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     256         y_true, y_pred, multioutput)
#     257     check_consistent_length(y_true, y_pred, sample_weight)
#
# ...

# %%
test
# Out:
# date
# 2015-08-23    29.875000
# 2015-08-24    30.750000
# 2015-08-25    32.000000
# 2015-08-26    32.000000
# 2015-08-27    32.500000
#                 ...
# 2016-12-28    17.217391
# 2016-12-29    15.238095
# 2016-12-30    14.095238
# 2016-12-31    15.052632
# 2017-01-01    10.000000
# Name: meantemp, Length: 498, dtype: float64

# %%
predictions = DataFrame(predictions, index=test.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1664
# -> 1665         mgr = BlockManager(blocks, axes)
#    1666         mgr._consolidate_inplace()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (5, 1), indices imply (498, 1)
#
# ...

# %%
plt.plot(test)
predictions.set_index(test.index, inplace=True)
plt.plot(predictions, color='red')
plt.title("Test Temperatures vs ARIMA Predictions")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6bba20703f8a> in <module>
#       1 plt.plot(test)
# ----> 2 predictions.set_index(test.index, inplace=True)
#       3 plt.plot(predictions, color='red')
#       4 plt.title("Test Temperatures vs ARIMA Predictions")
#
# AttributeError: 'list' object has no attribute 'set_index'

# %%
#Splitting data into quarters and comparing summary statistics across data
ser = passengers['#Passengers']
split = len(ser) // 4

X1 = ser[0:split]
X2 = ser[split:(2*split)] 
X3 = ser[(2*split):(3*split)] 
X4 = ser[(3*split):]

statistics = {'means': [X1.mean(), X2.mean(), X3.mean(), X4.mean()],
             'SDs': [X1.var(), X2.var(), X3.var(), X4.var()]}
stat = pd.DataFrame(statistics)
stat.head()

# %%
len(temp) / 2
# Out:
# 731.0

# %%
#Splitting temperature data into halves
ser = temp['meantemp']
split = len(ser) // 2

X1 = ser[0:split]
X2 = ser[split:] 


statistics = {'means': [X1.mean(), X2.mean()],
             'SDs': [X1.var(), X2.var()]}
stat = pd.DataFrame(statistics)
stat.head()
# Out:
#        means        SDs
# 0  24.887197  56.306534
# 1  26.103845  51.015529

# %%
#Passenger Dataset

result = adfuller(passengers)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
print("Thus we fail to reject the null hypothesis of our data passengers set being stationary")
# Out:
# ADF Statistic: 0.815369
# p-value: 0.991880
# Critical Values:
# 	1%: -3.482
# 	5%: -2.884
# 	10%: -2.579
# Thus we fail to reject the null hypothesis of our data passengers set being stationary

# %%
#Temperature Dataset

result = adfuller(temp)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
print("Thus we fail to reject the null hypothesis of our temperature dataset being stationary")
# Out:
# ADF Statistic: -2.021069
# p-value: 0.277412
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568
# Thus we fail to reject the null hypothesis of our temperature dataset being stationary

# %%
#Visualize

passengers.plot()
plt.ylabel("# of Passengers")
# Out:
# Text(0, 0.5, '# of Passengers')

# %%
temp.plot()
plt.ylabel("Mean Temperature C")
# Out:
# Text(0, 0.5, 'Mean Temperature C')

# %%
decompose = seasonal_decompose(temp['meantemp'], model='multiplicable', period=365)
decompose.seasonal.plot()
plt.ylabel("Seasonal")
# Out:
# Text(0, 0.5, 'Seasonal')

# %%
decompose.trend.plot()
plt.ylabel("Trend")
# Out:
# Text(0, 0.5, 'Trend')

# %%
decompose.resid.plot()
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
decompose.plot()

# %%
#Temp Analysis
decompose_add = seasonal_decompose(temp['meantemp'], model='additive', period=365)
decompose_add.plot()

# %%
#Differencing
dif_df = temp
dif_df["diff_temp"] = dif_df['meantemp'] - dif_df['meantemp'].shift(1)
dif_df.dropna(inplace=True)
dif_df["diff_temp"].plot()
plt.ylabel("First Order Differenced Temperature (C)")
# Out:
# Text(0, 0.5, 'First Order Differenced Temperature (C)')

# %%
dif_df = temp
dif_df["diff_temp"] = dif_df['meantemp'] - dif_df['meantemp'].shift(1)
dif_df.dropna(inplace=True)
dif_df["diff_temp"][:(len(dif_df["diff_temp"]) // 4)].plot(lw=2)
plt.ylabel("Second Order Differenced Temperature (C)")
# Out:
# Text(0, 0.5, 'Second Order Differenced Temperature (C)')

# %%
plt.plot(temp.meantemp.diff())
plot_acf(temp.meantemp.diff().dropna())

# %%
plt.plot(temp.meantemp.diff().diff())
plot_acf(temp.meantemp.diff().diff().dropna())

# %%
temp.head()
# Out:
#             meantemp  diff_temp
# date
# 2013-01-03  7.166667  -0.233333
# 2013-01-04  8.666667   1.500000
# 2013-01-05  6.000000  -2.666667
# 2013-01-06  7.000000   1.000000
# 2013-01-07  7.000000   0.000000

# %%
passengers
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
dif_df = passengers
dif_df["diff_passengers"] = dif_df['#Passengers'] - dif_df['#Passengers'].shift(1)
dif_df.dropna(inplace=True)
dif_df["diff_passengers"].plot()
plt.ylabel("Differenced Passengers Time Series")
plt.title("Passenger Dataset Differenced")
# Out:
# Text(0.5, 1.0, 'Passenger Dataset Differenced')

# %%
dif_df = passengers
dif_df["#Passengers"] = np.log(dif_df["#Passengers"])
dif_df["#Passengers"].plot()
plt.title("Passenger Dataset Log")
# Out:
# Text(0.5, 1.0, 'Passenger Dataset Log')

# %%
dif_df["diff_passengers"] = dif_df['#Passengers'] - dif_df['#Passengers'].shift(1)
dif_df.dropna(inplace=True)
dif_df["diff_passengers"].plot()
plt.ylabel("Differenced Passengers Time Series")
plt.title("Passenger Dataset Log + Differenced")
# Out:
# Text(0.5, 1.0, 'Passenger Dataset Log + Differenced')

# %%
dif_df = passengers
dif_df["#Passengers"] = np.sqrt(dif_df["#Passengers"])
dif_df["#Passengers"].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
dif_df["diff_passengers"] = dif_df['#Passengers'] - dif_df['#Passengers'].shift(1)
dif_df.dropna(inplace=True)
dif_df["diff_passengers"].plot()
plt.ylabel("Differenced Passengers Time Series")
# Out:
# Text(0, 0.5, 'Differenced Passengers Time Series')

# %%
! pip install pmdarima
from pmdarima.arima import auto_arima

# %%
X = passengers["#Passengers"]
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]

# %%
plt.plot(train)
plt.plot(test)
plt.title("Passengers Test vs Train Data")
# Out:
# Text(0.5, 1.0, 'Passengers Test vs Train Data')

# %%
arima_model = auto_arima(train, start_p=0, d=1, start_q=0, max_p=5, 
                         max_d=5, max_q=5,start_P=0, D=1, start_Q=0, 
                         max_P=5, max_D=5, max_Q=5, m=12, seasonal=True, 
                         error_action='warn', trace = True, 
                         supress_warnings=True, stepwise = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-489.162, Time=0.13 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-514.303, Time=0.21 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-521.274, Time=0.75 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=-497.713, Time=0.14 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=-519.256, Time=1.00 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=-519.174, Time=0.76 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=-516.233, Time=0.24 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=-517.468, Time=1.34 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=-513.108, Time=0.40 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=-517.863, Time=0.63 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=-519.924, Time=0.38 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=-519.485, Time=0.52 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=-517.295, Time=0.33 sec
# ...

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                  y   No. Observations:                   93
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 12)   Log Likelihood                 263.637
# Date:                            Sun, 03 Oct 2021   AIC                           -521.274
# Time:                                    22:29:17   BIC                           -514.128
# Sample:                                         0   HQIC                          -518.409
#                                              - 93
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4216      0.116     -3.640      0.000      -0.649      -0.195
# ma.S.L12      -0.6414      0.150     -4.275      0.000      -0.935      -0.347
# ...

# %%
predictions = pd.DataFrame(arima_model.predict(n_periods=len(test)), 
                           index=test.index)
predictions.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.figure(figsize=(8, 5))
plt.plot(train, label="Training")
plt.plot(test, label="Test")
plt.plot(predictions, label="Predicted")
plt.legend()

# %%
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,10))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# C:\Users\Jacob\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-eae2e34b3a05> in <module>
#       5         output = model_fit.forecast()
#       6         yhat = output[0]
# ----> 7         predictions.append(yhat)
#       8         obs = test[t]
#       9         history.append(obs)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ...

# %%
temp_outlier = (temp.values)
temp_outlier = np.append(temp_outlier, 55)
plt.hist(temp_outlier)
plt.title("temperature data with outlier incl.")
# Out:
# Text(0.5, 1.0, 'temperature data with outlier incl.')

# %%
#Z_scores of temperature data with outlier
z_scores = (temp_outlier - np.mean(temp_outlier)) / np.std(temp_outlier)
plt.hist(z_scores)
plt.title("Z-Scores of Said Temperature Data")
# Out:
# Text(0.5, 1.0, 'Z-Scores of Said Temperature Data')

# %%
filtered = [x * np.std(temp.values) + np.mean(temp.values) for x in z_scores if abs(x) <= 2.5]
plt.hist(filtered)
plt.title("Z-Scores of >2.5 Removed")
# Out:
# Text(0.5, 1.0, 'Z-Scores of >2.5 Removed')

# %%
plt.hist(temp)
plt.title("Original Temp Data")
# Out:
# Text(0.5, 1.0, 'Original Temp Data')

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=1).fit(temp.values)
labels = clustering.labels_

# %%
#Noisy samples are given -1 values
label_set = set(labels)
label_set
# Out:
# {-1, 0}

# %%
num_outliers = sum([True for x in labels if x == -1])
num_outliers
# Out:
# 38

# %%
plt.scatter(temp.values, labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-af7df410616c> in <module>
# ----> 1 plt.scatter(temp.values, labels)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...

# %%
with_outlier = temp.values.tolist() + [[55]]

# %%
with_outlier = temp.values + np.array(55)
with_outlier
# Out:
# array([[62.16666667, 54.76666667],
#        [63.66666667, 56.5       ],
#        [61.        , 52.33333333],
#        ...,
#        [69.0952381 , 53.85714286],
#        [70.05263158, 55.95739348],
#        [65.        , 49.94736842]])

# %%
clustering = DBSCAN(eps=1).fit(with_outlier)
labels = clustering.labels_
label_set = set(labels)
print(label_set)
num_outliers = sum([True for x in labels if x == -1])
num_outliers
# Out:
# {0, -1}
# 38

# %%
plt.scatter(with_outlier, labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-51d2a96899ab> in <module>
# ----> 1 plt.scatter(with_outlier, labels)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...

# %%
clustering = DBSCAN(eps=1).fit(temp)
labels = clustering.labels_
label_set = set(labels)
print(label_set)
num_outliers = sum([True for x in labels if x == -1])
num_outliers
# Out:
# {0, -1}
# 38

# %%
plt.scatter(temp, labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-5b90328a6560> in <module>
# ----> 1 plt.scatter(temp, labels)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...

# %%
passengers[0:50]
# Out:
#             #Passengers  diff_passengers
# Month
# 1949-04-01     2.204498        -0.005208
# 1949-05-01     2.189929        -0.014569
# 1949-06-01     2.214785         0.024856
# 1949-07-01     2.235445         0.020659
# 1949-08-01     2.235445         0.000000
# 1949-09-01     2.216451        -0.018994
# 1949-10-01     2.186121        -0.030330
# 1949-11-01     2.155085        -0.031036
# 1949-12-01     2.184190         0.029105
# 1950-01-01     2.178287        -0.005903
# 1950-02-01     2.199155         0.020868
# 1950-03-01     2.224581         0.025426
# 1950-04-01     2.214785        -0.009795
# 1950-05-01     2.197342        -0.017443
# 1950-06-01     2.236950         0.039608
# 1950-07-01     2.266230         0.029280
# 1950-08-01     2.266230         0.000000
# 1950-09-01     2.250021        -0.016209
# 1950-10-01     2.211413        -0.038608
# 1950-11-01     2.176281        -0.035133
# 1950-12-01     2.222981         0.046700
# 1951-01-01     2.230859         0.007879
# ...

# %%
passengers.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
outlier_passenger = passengers
outlier_passenger["#Passengers"][10] = 300
outlier_passenger["#Passengers"][43] = 140

# %%
outlier_passenger.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
decompose = seasonal_decompose(outlier_passenger['#Passengers'], model='multiplicable', period=12)
decompose.plot()

# %%
decompose.resid.plot()
plt.title("Passenger w/Outliers Residual Plot")
# Out:
# Text(0.5, 1.0, 'Passenger w/Outliers Residual Plot')

# %%
plt.rc('figure',figsize=(12,6))
plt.rc('font',size=15)
fig, ax = plt.subplots()
x = decompose.resid.index
y = decompose.resid.values
ax.plot_date(x, y, color='black',linestyle='--')
ax.annotate('Anomaly', (mdates.date2num(x[35]), y[35]), xytext=(30, 20),
          textcoords='offset points', color='red',arrowprops=dict(facecolor='red',arrowstyle='fancy'))
fig.autofmt_xdate()
plt.title("Passenger Data With Manually Plugged Outliers")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-a62b038c34e5> in <module>
#       5 y = decompose.resid.values
#       6 ax.plot_date(x, y, color='black',linestyle='--')
# ----> 7 ax.annotate('Anomaly', (mdates.date2num(x[35]), y[35]), xytext=(30, 20),
#       8           textcoords='offset points', color='red',arrowprops=dict(facecolor='red',arrowstyle='fancy'))
#       9 fig.autofmt_xdate()
#
# NameError: name 'mdates' is not defined

# %%
x = decompose.resid.index
y = decompose.resid.values
decompose.resid.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.plot(passengers.index, passengers["#Passengers"])
plt.title("Passengers With Anomalies")
# Out:
# Text(0.5, 1.0, 'Passengers With Anomalies')

# %%
#Isolation Forests
from sklearn.ensemble import IsolationForest
model = IsolationForest(contamination=0.02)
model.fit(outlier_passenger[["#Passengers"]])
# Out:
# IsolationForest(contamination=0.02)

# %%
model.get_params()
# Out:
# {'behaviour': 'deprecated',
#  'bootstrap': False,
#  'contamination': 0.02,
#  'max_features': 1.0,
#  'max_samples': 'auto',
#  'n_estimators': 100,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
outlier_passenger['scores'] = model.decision_function(outlier_passenger[['#Passengers']])

outlier_passenger['anomaly_score'] = model.predict(outlier_passenger[['#Passengers']])

anomalies = outlier_passenger[outlier_passenger['anomaly_score']==-1]

anomalies.head()
# Out:
#             #Passengers  diff_passengers    scores  anomaly_score
# Month
# 1949-11-01     2.155085        -0.031036 -0.032115             -1
# 1950-02-01   300.000000         0.020868 -0.260545             -1
# 1952-11-01   140.000000        -0.022975 -0.222952             -1

# %%
plt.plot(outlier_passenger)
plt.scatter(outlier_passenger.index, outlier_passenger["#Passengers"], facecolors="black")
plt.scatter(anomalies.index, anomalies["#Passengers"], facecolor="Red")
plt.title("Passenger Data Outlier Detection")
# Out:
# Text(0.5, 1.0, 'Passenger Data Outlier Detection')

# %%
clustering = DBSCAN(eps=1).fit(outlier_temp)
labels = clustering.labels_
label_set = set(labels)
print(label_set)
num_outliers = sum([True for x in labels if x == -1])
num_outliers

# %%
outlier_temp[0:300].plot()

# %%
plt.scatter(outlier_temp, labels)

# %%
decompose.resid.plot()
plt.ylabel("Residuals")

# %%
decompose.plot()

# %%
anom = temp
anom['day'] = [i.day for i in anom.index]
anom['day_name'] = [i.day_name() for i in anom.index]
anom['day_of_year'] = [i.dayofyear for i in anom.index]
anom['week_of_year'] = [i.weekofyear for i in anom.index]
anom['is_weekday'] = [i.isoweekday() for i in anom.index]
anom.head()

# %%
! pip install pycaret

# %%
from pycaret.anomaly import *
s = setup(anom, session_id = 123)

# %%
pip install pyod
